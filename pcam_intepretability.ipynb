# %%
# !git clone https://github.com/allen-ajith/pcam-interpretability.git
# %cd pcam-interpretability

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")

# Login to Hugging Face Hub
login(token=hf_token)

# %%
# !pip install -r requirements.txt

# %%
#!python test_upload_to_hf.py

# %%
# !python train.py --model_name resnet50 --epochs 20 --batch_size 64 --lr 1e-3 --optimizer sgd --scheduler step

# %%
# !python train.py --model_name dino-vits16 --epochs 30 --batch_size 128 --lr 1e-5 --optimizer adamw --scheduler cosine

# %%
# !python train.py --model_name dino-vits16 --epochs 30 --batch_size 128 --lr 1e-5 --optimizer adamw --scheduler cosine
